# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98

class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)
        return x
      
    def put_data(self, item):
        self.data.append(item)
        
    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + gamma * R
            loss = -torch.log(prob) * R
            loss.backward()
        self.optimizer.step()
        self.data = []

def main():
    env = gym.make('CartPole-v1')
    pi = Policy()
    score = 0.0
    print_interval = 20
    
    
    for n_epi in range(10000):
        s, _ = env.reset()
        done = False
        
        while not done: # CartPole-v1 forced to terminates at 500 step.
            prob = pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample()
            s_prime, r, done, truncated, info = env.step(a.item())
            pi.put_data((r,prob[a]))
            s = s_prime
            score += r
            
        pi.train_net()
        
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
            score = 0.0
    env.close()
    
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gym
#       2 import torch
#       3 import torch.nn as nn
#
# ModuleNotFoundError: No module named 'gym'

# %%
# !pip install gym
# Out:
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 9.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from gym) (1.22.3)
# Collecting cloudpickle>=1.2.0 (from gym)
#   Obtaining dependency information for cloudpickle>=1.2.0 from https://files.pythonhosted.org/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl.metadata
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting gym-notices>=0.0.4 (from gym)
#   Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from gym) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gym) (3.11.0)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827620 sha256=9aad6d496f3145416bd53d882ad578d986a52bba06f4df4c52a9bb804e7b726b
#   Stored in directory: /Users/choejm/Library/Caches/pip/wheels/17/79/65/7afedc162d858b02708a3b8f7a6dd5b1000dcd5b0f894f7cc1
# Successfully built gym
# Installing collected packages: gym-notices, cloudpickle, gym
# Successfully installed cloudpickle-3.0.0 gym-0.26.2 gym-notices-0.0.8

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98

class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)
        return x
      
    def put_data(self, item):
        self.data.append(item)
        
    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + gamma * R
            loss = -torch.log(prob) * R
            loss.backward()
        self.optimizer.step()
        self.data = []

def main():
    env = gym.make('CartPole-v1')
    pi = Policy()
    score = 0.0
    print_interval = 20
    
    
    for n_epi in range(10000):
        s, _ = env.reset()
        done = False
        
        while not done: # CartPole-v1 forced to terminates at 500 step.
            prob = pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample()
            s_prime, r, done, truncated, info = env.step(a.item())
            pi.put_data((r,prob[a]))
            s = s_prime
            score += r
            
        pi.train_net()
        
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
            score = 0.0
    env.close()
    
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import gym
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !pip3 install torch torchvision
# Out:
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/c5/b4/b7fb1f32a327ffff695cb3d876c1b0ad5261935cb816b92287149f2212a6/torch-2.1.2-cp38-none-macosx_11_0_arm64.whl.metadata
#   Downloading torch-2.1.2-cp38-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting torchvision
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/64/53/3b757838d3f557b2c47fd694644e44754ae34e570519b44b5d9a6c8527ad/torchvision-0.16.2-cp38-cp38-macosx_11_0_arm64.whl.metadata
#   Downloading torchvision-0.16.2-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from torch) (3.13.0)
# Requirement already satisfied: typing-extensions in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from torch) (4.5.0)
# Collecting sympy (from torch)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 14.6 MB/s eta 0:00:0000:0100:01
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from torch) (3.1.2)
# Collecting fsspec (from torch)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/70/25/fab23259a52ece5670dcb8452e1af34b89e6135ecc17cd4b54b4b479eac6/fsspec-2023.12.2-py3-none-any.whl.metadata
#   Downloading fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from torchvision) (1.22.3)
# Requirement already satisfied: requests in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/choejm/miniforge3/envs/test/lib/python3.8/site-packages (from requests->torchvision) (2023.7.22)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 15.3 MB/s eta 0:00:00
# Downloading torch-2.1.2-cp38-none-macosx_11_0_arm64.whl (59.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 22.2 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.16.2-cp38-cp38-macosx_11_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.8 MB/s eta 0:00:00a 0:00:01
# Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 15.2 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, networkx, fsspec, torch, torchvision
# Successfully installed fsspec-2023.12.2 mpmath-1.3.0 networkx-3.1 sympy-1.12 torch-2.1.2 torchvision-0.16.2

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma         = 0.98

class Policy(nn.Module):
    def __init__(self):
        super(Policy, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)
        return x
      
    def put_data(self, item):
        self.data.append(item)
        
    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + gamma * R
            loss = -torch.log(prob) * R
            loss.backward()
        self.optimizer.step()
        self.data = []

def main():
    env = gym.make('CartPole-v1')
    pi = Policy()
    score = 0.0
    print_interval = 20
    
    
    for n_epi in range(10000):
        s, _ = env.reset()
        done = False
        
        while not done: # CartPole-v1 forced to terminates at 500 step.
            prob = pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample()
            s_prime, r, done, truncated, info = env.step(a.item())
            pi.put_data((r,prob[a]))
            s = s_prime
            score += r
            
        pi.train_net()
        
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
            score = 0.0
    env.close()
    
if __name__ == '__main__':
    main()
# Out:
# # of episode :20, avg score : 20.05
# # of episode :40, avg score : 20.0
# # of episode :60, avg score : 26.85
# # of episode :80, avg score : 25.45
# # of episode :100, avg score : 18.65
# # of episode :120, avg score : 30.95
# # of episode :140, avg score : 23.1
# # of episode :160, avg score : 22.3
# # of episode :180, avg score : 26.65
# # of episode :200, avg score : 21.65
# # of episode :220, avg score : 29.2
# # of episode :240, avg score : 22.55
# # of episode :260, avg score : 26.85
# # of episode :280, avg score : 30.9
# # of episode :300, avg score : 32.2
# # of episode :320, avg score : 29.85
# # of episode :340, avg score : 27.15
# # of episode :360, avg score : 28.65
# # of episode :380, avg score : 35.0
# # of episode :400, avg score : 25.65
# # of episode :420, avg score : 32.8
# # of episode :440, avg score : 45.9
# # of episode :460, avg score : 35.6
# # of episode :480, avg score : 41.0
# # of episode :500, avg score : 35.6
# # of episode :520, avg score : 40.15
# # of episode :540, avg score : 36.3
# # of episode :560, avg score : 38.1
# # of episode :580, avg score : 37.55
# # of episode :600, avg score : 41.1
# # of episode :620, avg score : 36.1
# # of episode :640, avg score : 38.7
# # of episode :660, avg score : 49.75
# # of episode :680, avg score : 37.25
# # of episode :700, avg score : 39.85
# # of episode :720, avg score : 46.7
# # of episode :740, avg score : 44.45
# # of episode :760, avg score : 41.9
# # of episode :780, avg score : 63.8
# # of episode :800, avg score : 50.2
# # of episode :820, avg score : 51.55
# # of episode :840, avg score : 65.65
# # of episode :860, avg score : 38.0
# # of episode :880, avg score : 60.55
# # of episode :900, avg score : 60.65
# # of episode :920, avg score : 86.65
# # of episode :940, avg score : 85.05
# # of episode :960, avg score : 95.55
# # of episode :980, avg score : 78.85
# # of episode :1000, avg score : 79.7
# # of episode :1020, avg score : 82.7
# # of episode :1040, avg score : 105.75
# # of episode :1060, avg score : 93.05
# # of episode :1080, avg score : 84.7
# # of episode :1100, avg score : 158.75
# # of episode :1120, avg score : 118.9
# # of episode :1140, avg score : 125.5
# # of episode :1160, avg score : 106.05
# # of episode :1180, avg score : 139.5
# # of episode :1200, avg score : 140.75
# # of episode :1220, avg score : 138.15
# # of episode :1240, avg score : 147.2
# # of episode :1260, avg score : 161.15
# # of episode :1280, avg score : 194.35
# # of episode :1300, avg score : 153.95
# # of episode :1320, avg score : 193.85
# # of episode :1340, avg score : 156.55
# # of episode :1360, avg score : 137.4
# # of episode :1380, avg score : 168.8
# # of episode :1400, avg score : 161.75
# # of episode :1420, avg score : 157.55
# # of episode :1440, avg score : 170.45
# # of episode :1460, avg score : 198.2
# # of episode :1480, avg score : 218.95
# # of episode :1500, avg score : 212.15
# # of episode :1520, avg score : 176.05
# # of episode :1540, avg score : 174.1
# # of episode :1560, avg score : 206.85
# # of episode :1580, avg score : 205.95
# # of episode :1600, avg score : 186.3
# # of episode :1620, avg score : 241.25
# # of episode :1640, avg score : 224.6
# # of episode :1660, avg score : 182.95
# # of episode :1680, avg score : 268.2
# # of episode :1700, avg score : 230.7
# # of episode :1720, avg score : 175.25
# # of episode :1740, avg score : 217.4
# # of episode :1760, avg score : 228.75
# # of episode :1780, avg score : 258.1
# # of episode :1800, avg score : 235.25
# # of episode :1820, avg score : 211.55
# # of episode :1840, avg score : 243.05
# # of episode :1860, avg score : 277.4
# # of episode :1880, avg score : 246.3
# # of episode :1900, avg score : 258.85
# # of episode :1920, avg score : 226.45
# # of episode :1940, avg score : 189.85
# # of episode :1960, avg score : 161.6
# # of episode :1980, avg score : 241.9
# # of episode :2000, avg score : 310.65
# # of episode :2020, avg score : 229.15
# # of episode :2040, avg score : 256.2
# # of episode :2060, avg score : 255.95
# # of episode :2080, avg score : 272.95
# # of episode :2100, avg score : 317.7
# # of episode :2120, avg score : 254.6
# # of episode :2140, avg score : 272.2
# # of episode :2160, avg score : 319.95
# # of episode :2180, avg score : 279.0
# # of episode :2200, avg score : 271.65
# # of episode :2220, avg score : 316.65
# # of episode :2240, avg score : 272.75
# # of episode :2260, avg score : 336.5
# # of episode :2280, avg score : 279.95
# # of episode :2300, avg score : 264.8
# # of episode :2320, avg score : 263.85
# # of episode :2340, avg score : 225.65
# # of episode :2360, avg score : 233.05
# # of episode :2380, avg score : 275.75
# # of episode :2400, avg score : 215.7
# # of episode :2420, avg score : 294.55
# # of episode :2440, avg score : 249.0
# # of episode :2460, avg score : 331.55
# # of episode :2480, avg score : 377.0
# # of episode :2500, avg score : 280.65
# # of episode :2520, avg score : 294.65
# # of episode :2540, avg score : 295.35
# # of episode :2560, avg score : 291.5
# # of episode :2580, avg score : 356.8
# # of episode :2600, avg score : 300.85
# # of episode :2620, avg score : 360.3
# # of episode :2640, avg score : 278.95
# # of episode :2660, avg score : 362.8
# # of episode :2680, avg score : 335.05
# # of episode :2700, avg score : 385.0
# # of episode :2720, avg score : 342.75
# # of episode :2740, avg score : 303.95
# # of episode :2760, avg score : 428.7
# # of episode :2780, avg score : 339.6
# # of episode :2800, avg score : 327.2
# # of episode :2820, avg score : 317.4
# # of episode :2840, avg score : 341.85
# # of episode :2860, avg score : 320.35
# # of episode :2880, avg score : 297.3
# # of episode :2900, avg score : 288.1
# # of episode :2920, avg score : 343.35
# # of episode :2940, avg score : 329.25
# # of episode :2960, avg score : 374.1
# # of episode :2980, avg score : 338.95
# # of episode :3000, avg score : 408.75
# # of episode :3020, avg score : 354.95
# # of episode :3040, avg score : 362.1
# # of episode :3060, avg score : 298.95
# # of episode :3080, avg score : 308.3
# # of episode :3100, avg score : 276.15
# # of episode :3120, avg score : 390.7
# # of episode :3140, avg score : 386.35
# # of episode :3160, avg score : 399.35
# # of episode :3180, avg score : 520.8
# # of episode :3200, avg score : 390.95
# # of episode :3220, avg score : 475.9
# # of episode :3240, avg score : 462.8
# # of episode :3260, avg score : 416.2
# # of episode :3280, avg score : 423.0
# # of episode :3300, avg score : 445.75
# # of episode :3320, avg score : 441.8
# # of episode :3340, avg score : 417.65
# # of episode :3360, avg score : 381.55
# # of episode :3380, avg score : 497.75
# # of episode :3400, avg score : 427.6
# # of episode :3420, avg score : 411.5
# # of episode :3440, avg score : 372.4
# # of episode :3460, avg score : 529.05
# # of episode :3480, avg score : 556.25
# # of episode :3500, avg score : 414.15
# # of episode :3520, avg score : 455.25
# # of episode :3540, avg score : 398.15
# # of episode :3560, avg score : 500.85
# # of episode :3580, avg score : 519.5
# # of episode :3600, avg score : 436.8
# # of episode :3620, avg score : 503.2
# # of episode :3640, avg score : 569.35
# # of episode :3660, avg score : 610.8
# # of episode :3680, avg score : 668.85
# # of episode :3700, avg score : 466.7
# # of episode :3720, avg score : 457.0
# # of episode :3740, avg score : 663.8
# # of episode :3760, avg score : 685.15
# # of episode :3780, avg score : 538.3
# # of episode :3800, avg score : 551.75
# # of episode :3820, avg score : 429.7
# # of episode :3840, avg score : 556.25
# # of episode :3860, avg score : 492.25
# # of episode :3880, avg score : 610.05
# # of episode :3900, avg score : 744.6
# # of episode :3920, avg score : 620.9
# # of episode :3940, avg score : 918.8
# # of episode :3960, avg score : 762.6
# # of episode :3980, avg score : 710.0
# # of episode :4000, avg score : 731.1
# # of episode :4020, avg score : 583.05
# # of episode :4040, avg score : 524.6
# # of episode :4060, avg score : 516.0
# # of episode :4080, avg score : 606.3
# # of episode :4100, avg score : 723.5
# # of episode :4120, avg score : 883.2
# # of episode :4140, avg score : 693.2
# # of episode :4160, avg score : 762.75
# # of episode :4180, avg score : 502.15
# # of episode :4200, avg score : 386.85
# # of episode :4220, avg score : 360.75
# # of episode :4240, avg score : 411.1
# # of episode :4260, avg score : 492.3
# # of episode :4280, avg score : 475.5
# # of episode :4300, avg score : 335.0
# # of episode :4320, avg score : 413.4
# # of episode :4340, avg score : 520.7
# # of episode :4360, avg score : 365.45
# # of episode :4380, avg score : 395.15
# # of episode :4400, avg score : 345.4
# # of episode :4420, avg score : 362.15
# # of episode :4440, avg score : 371.55
# # of episode :4460, avg score : 416.45
# # of episode :4480, avg score : 467.0
# # of episode :4500, avg score : 490.25
# # of episode :4520, avg score : 581.8
# # of episode :4540, avg score : 588.4
# # of episode :4560, avg score : 650.7
# # of episode :4580, avg score : 829.0
# # of episode :4600, avg score : 978.85
# # of episode :4620, avg score : 964.8
# # of episode :4640, avg score : 1212.95
# # of episode :4660, avg score : 1733.55
# # of episode :4680, avg score : 1156.0
# # of episode :4700, avg score : 1096.0
# # of episode :4720, avg score : 1184.45
# # of episode :4740, avg score : 1204.0
# # of episode :4760, avg score : 1034.7
# # of episode :4780, avg score : 969.0
# # of episode :4800, avg score : 843.15
# # of episode :4820, avg score : 547.3
# # of episode :4840, avg score : 481.05
# # of episode :4860, avg score : 538.15
# # of episode :4880, avg score : 504.75
# # of episode :4900, avg score : 587.3
# # of episode :4920, avg score : 728.0
# # of episode :4940, avg score : 721.95
# # of episode :4960, avg score : 936.95
# # of episode :4980, avg score : 838.45
# # of episode :5000, avg score : 1232.0
# # of episode :5020, avg score : 912.35
# # of episode :5040, avg score : 1018.25
# # of episode :5060, avg score : 890.05
# # of episode :5080, avg score : 927.95
# # of episode :5100, avg score : 1286.35
# # of episode :5120, avg score : 1455.7
# # of episode :5140, avg score : 898.95
# # of episode :5160, avg score : 1154.75
# # of episode :5180, avg score : 2135.85
# # of episode :5200, avg score : 2053.35
# # of episode :5220, avg score : 1478.95
# # of episode :5240, avg score : 2283.0
# # of episode :5260, avg score : 1853.4
# # of episode :5280, avg score : 2408.45
# # of episode :5300, avg score : 2765.4
# # of episode :5320, avg score : 2328.4
# # of episode :5340, avg score : 3321.75
# # of episode :5360, avg score : 3044.2
# # of episode :5380, avg score : 3456.0
# # of episode :5400, avg score : 2533.4
# # of episode :5420, avg score : 2096.05
# # of episode :5440, avg score : 1554.25
# # of episode :5460, avg score : 3489.35
# # of episode :5480, avg score : 2803.2
# # of episode :5500, avg score : 2358.25
# # of episode :5520, avg score : 3164.6
# # of episode :5540, avg score : 2055.0
# # of episode :5560, avg score : 1946.25
# # of episode :5580, avg score : 2396.45
# # of episode :5600, avg score : 2626.25
# # of episode :5620, avg score : 2817.25
# # of episode :5640, avg score : 1250.45
# # of episode :5660, avg score : 2370.45
# # of episode :5680, avg score : 4718.8
# # of episode :5700, avg score : 2811.9
# # of episode :5720, avg score : 1555.75
# # of episode :5740, avg score : 1155.75
# # of episode :5760, avg score : 2096.25
# # of episode :5780, avg score : 3066.15
# # of episode :5800, avg score : 4151.85
# # of episode :5820, avg score : 3462.7
# # of episode :5840, avg score : 4151.15
# # of episode :5860, avg score : 3031.25
# # of episode :5880, avg score : 2135.6
# # of episode :5900, avg score : 761.1
# # of episode :5920, avg score : 781.25
# # of episode :5940, avg score : 758.3
# # of episode :5960, avg score : 1083.95
# # of episode :5980, avg score : 1534.25
# # of episode :6000, avg score : 1625.6
# # of episode :6020, avg score : 3851.45
# # of episode :6040, avg score : 4189.25
# # of episode :6060, avg score : 4352.5
# # of episode :6080, avg score : 1673.65
# # of episode :6100, avg score : 1495.7
# # of episode :6120, avg score : 2514.2
# # of episode :6140, avg score : 4441.3
# # of episode :6160, avg score : 5571.75
# # of episode :6180, avg score : 10161.4
# # of episode :6200, avg score : 4792.95
# # of episode :6220, avg score : 3623.45
# # of episode :6240, avg score : 2216.1
# # of episode :6260, avg score : 2335.2
# # of episode :6280, avg score : 2659.25
# # of episode :6300, avg score : 2677.05
# # of episode :6320, avg score : 1166.2
# # of episode :6340, avg score : 1079.8
# # of episode :6360, avg score : 1177.55
# # of episode :6380, avg score : 1227.15
# # of episode :6400, avg score : 2152.9
# # of episode :6420, avg score : 2005.1
# # of episode :6440, avg score : 2276.6
# # of episode :6460, avg score : 1588.9
# # of episode :6480, avg score : 2365.45
# # of episode :6500, avg score : 3651.45
# # of episode :6520, avg score : 2714.0
# # of episode :6540, avg score : 3191.55
# # of episode :6560, avg score : 1748.0
# # of episode :6580, avg score : 1322.95
# # of episode :6600, avg score : 1829.0
# # of episode :6620, avg score : 3714.7
# # of episode :6640, avg score : 3540.65
# # of episode :6660, avg score : 4000.15
# # of episode :6680, avg score : 3898.2
# # of episode :6700, avg score : 5981.35
# # of episode :6720, avg score : 4363.0
# # of episode :6740, avg score : 5376.95
# # of episode :6760, avg score : 3960.05
# # of episode :6780, avg score : 4643.0
# # of episode :6800, avg score : 2709.85
# # of episode :6820, avg score : 3478.7
# # of episode :6840, avg score : 4136.35
# # of episode :6860, avg score : 2504.75
# # of episode :6880, avg score : 3790.9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 67
#      64     env.close()
#      66 if __name__ == '__main__':
# ---> 67     main()
#
# Cell In[5], line 55, in main()
#      53 a = m.sample()
#      54 s_prime, r, done, truncated, info = env.step(a.item())
# ---> 55 pi.put_data((r,prob[a]))
#      56 s = s_prime
#      57 score += r
#
# KeyboardInterrupt:
