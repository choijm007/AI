# %%
import cv2
import face_recognition
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("./image/MESSI.jpg")
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_encoding = face_recognition.face_encodings(rgb_img)[0]

img2 = cv2.imread("./image/juwan2.jpg")
rgb_img2=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img_encoding2 = face_recognition.face_encodings(rgb_img2)[0]

result=face_recognition.compare_faces([img_encoding], img_encoding2)
print("Result: ", result)


# cv2.imshow("Img", img)
# cv2.imshow("Img 2", img2)
cv2.waitKey(0)
# Out:
# Result:  [False]
# -1

# %%
def store(user_name, img)
    file_name="image/{}.jpg".format(user_name)
    cv2.imwrite(file_name, img)

# %%
img = cv2.imread("./image/jaemin2.jpg")
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imshow("Img ",img)
cv2.waitKey(0)

# %%
image = face_recognition.load_image_file("./image/jaemin1.jpg")
face_landmarks_list = face_recognition.face_landmarks(image)
print(face_landmarks_list)

# %%
image = face_recognition.load_image_file("./image/MESSI.jpg")
face_locations = face_recognition.face_locations(image)
plt.imshow(image)
print(face_locations)
for face_location in face_locations:        
        plt.plot(face_location[1], face_location[0], 'bo')
        plt.plot(face_location[1], face_location[2], 'bo')
        plt.plot(face_location[3], face_location[2], 'bo')
        plt.plot(face_location[3], face_location[0], 'bo')
plt.show()
# Out:
# [(139, 225, 268, 96)]

# %%
image = face_recognition.load_image_file("./image/juwan2.jpg")
face_locations = face_recognition.face_locations(image)
plt.imshow(image)
print(face_locations)
for face_location in face_locations:        
        plt.plot(face_location[1], face_location[0], 'bo')
        plt.plot(face_location[1], face_location[2], 'bo')
        plt.plot(face_location[3], face_location[2], 'bo')
        plt.plot(face_location[3], face_location[0], 'bo')
plt.show()
# Out:
# [(276, 261, 319, 218)]
